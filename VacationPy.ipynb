# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f993de8d-4e88-4306-bb07-598a3af8af9d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f17d4dfe-6f6b-4036-a8cb-a259ee5454f7":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"4a94d806ffcd4c538c4564ee151b73d3","client_comm_id":"8a772f80986941e4a669ffdfa27980f0"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"f17d4dfe-6f6b-4036-a8cb-a259ee5454f7","roots":{"p1002":"f993de8d-4e88-4306-bb07-598a3af8af9d"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0        0          cabo san lucas  22.8909 -109.9124     69.51        70
# 1        1                   tiksi  71.6872  128.8694     16.65        83
# 2        2  hawaiian paradise park  19.5933 -154.9731     69.03        98
# 3        3            antonio enes -16.2325   39.9086     81.82        68
# 4        4       port-aux-francais -49.3500   70.2167     39.13        78
#
#    Cloudiness  Wind Speed Country        Date
# 0          81       10.31      MX  1711895712
# 1         100       19.66      RU  1711895713
# 2         100        3.44      US  1711895713
# 3          48       12.84      MZ  1711895714
# 4         100       13.27      TF  1711895714

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
# Create a scatter plot using hvplot.points
city_map = city_data_df.hvplot.points(
    x='Lng',
    y='Lat',
    c='Humidity',
    colormap='viridis',  # You can choose a different colormap if desired
    size='Humidity',     # Set the size of points based on humidity
    title='City Humidity',
    xlabel='Longitude',
    ylabel='Latitude',
    hover_cols=['City', 'Humidity'],
    #hover_cols= 'all',
    colorbar=True,
    grid=True,
    coastline=True,
    tiles = True,
    frame_width = 700,
    frame_height = 500,
)

# Display the map
city_map
# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .WMTS.I      :WMTS   [Longitude,Latitude]
#    .Points.I    :Points   [Lng,Lat]   (Humidity,City)
#    .Coastline.I :Feature   [Longitude,Latitude]

# %%
# Narrow down cities that fit criteria and drop any results with null values
# YOUR CODE HERE
# Define ideal weather conditions
ideal_temp_min = 70
ideal_temp_max = 80
ideal_humidity_max = 70
ideal_wind_speed_max = 10

# Filter the DataFrame based on ideal conditions
ideal_weather_df = city_data_df[
    (city_data_df['Max Temp'] >= ideal_temp_min) &
    (city_data_df['Max Temp'] <= ideal_temp_max) &
    (city_data_df['Humidity'] <= ideal_humidity_max) &
    (city_data_df['Wind Speed'] <= ideal_wind_speed_max)
]

# Drop any rows with null values
# YOUR CODE HERE
# Drop rows with null values
ideal_weather_df = ideal_weather_df.dropna()

# Display sample data
# YOUR CODE HERE
# Display the filtered DataFrame
#ideal_weather_df.to_csv("output_data/ideal_weather_df.csv", index=False)
ideal_weather_df.head(len(ideal_weather_df))
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 19        19                constantia  44.1833   28.6500     70.70        65
# 39        39                  tartouss  34.8890   35.8866     72.21        65
# 53        53     santa ana hueytlalpan  20.1833  -98.3000     72.52        23
# 119      119                   petauke -14.2426   31.3253     75.96        55
# 125      125                 albertina -22.2008  -46.6158     78.39        46
# 176      176                  mianyang  31.4593  104.7542     70.97        55
# 194      194                fort bragg  35.1390  -79.0060     77.20        46
# 211      211                   pacocha -17.5833  -71.3333     74.57        70
# 226      226                      tura  25.5198   90.2201     78.76        35
# 237      237              bolanikhodan  22.1000   85.3167     78.06        45
# 246      246        san jose de jachal -30.2406  -68.7469     71.65        25
# 265      265        chilapa de alvarez  17.6000  -99.1667     77.49        39
# 280      280                greenville  35.6127  -77.3663     74.14        46
# 293      293          puerto escondido  15.8500  -97.0667     79.63        61
# 309      309                    aldama  22.9167  -98.0667     78.80        66
# 365      365                   korocha  50.8107   37.1953     72.32        55
# 399      399                   kuruman -27.4524   23.4325     77.32        36
# 401      401                   kosmach  48.7509   24.3673     70.32        41
# 410      410                  castanos  26.7833 -101.4167     75.92        46
# 432      432         'alaqahdari dishu  30.4374   63.3130     71.94        11
# 441      441                calingasta -31.3308  -69.4078     77.29        29
# 512      512                 kurchatov  51.6601   35.6521     72.01        61
# 550      550                     chios  38.3678   26.1358     73.26        49
# 556      556                  tomatlan  19.9333 -105.2500     77.76        38
# 557      557  san pablo villa de mitla  16.9167  -96.4000     75.74        42
# 570      570       parras de la fuente  25.4167 -102.1833     72.81        15
#
#      Cloudiness  Wind Speed Country        Date
# 19           86        9.04      RO  1711895724
# 39           87        3.31      SY  1711895737
# 53           65        3.04      MX  1711895745
# 119          94        9.04      ZM  1711895785
# 125          17        4.90      BR  1711895787
# 176         100        1.54      CN  1711895634
# 194           0        4.61      US  1711895823
# 211          99        7.02      PE  1711895835
# 226           0        3.40      IN  1711895843
# 237          77        5.39      IN  1711895852
# 246           0        5.26      AR  1711895856
# 265           5        1.68      MX  1711895863
# 280           0        4.00      US  1711895871
# 293           0        3.44      MX  1711895878
# 309          86        9.44      MX  1711895885
# 365           1        7.94      RU  1711895919
# 399          94        7.67      ZA  1711895943
# 401          76        6.38      UA  1711895944
# 410          84        3.76      MX  1711895751
# 432         100        6.85      AF  1711895958
# 441           0        1.68      AR  1711895964
# 512          16        8.97      RU  1711895998
# 550           0        4.61      GR  1711896012
# 556          12        2.57      MX  1711896014
# 557           1        2.01      MX  1711896014
# 570          77        6.49      MX  1711895957

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ''

# Display sample data
# YOUR CODE HERE
hotel_df.to_csv("output_data/hotel_df.csv", index=False)
hotel_df.head(len(hotel_df))
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 0            cabo san lucas      MX  22.8909 -109.9124        70
# 1                     tiksi      RU  71.6872  128.8694        83
# 2    hawaiian paradise park      US  19.5933 -154.9731        98
# 3              antonio enes      MZ -16.2325   39.9086        68
# 4         port-aux-francais      TF -49.3500   70.2167        78
# ..                      ...     ...      ...       ...       ...        ...
# 587                kolokani      ML  13.5728   -8.0339        13
# 588           guajara mirim      BR -10.7828  -65.3394        74
# 589       bikenibeu village      KI   1.3673  173.1241        84
# 590                  tromso      NO  69.6496   18.9570        55
# 591          candido mendes      BR  -1.4467  -45.7167        61
#
# [592 rows x 6 columns]

# %%
# Set parameters to search for a hotel
radius = 5000 # YOUR CODE HERE
params = {
    # YOUR CODE HERE
    "radius": radius,
    "limit": 1,
    "categories":f"accommodation.hotel",
    "apiKey": geoapify_key 
}
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    # YOUR CODE HERE
    lat = row['Lat']
    lng = row['Lng']
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}" # YOUR CODE HERE
    params["bias"] = f"proximity:{lng},{lat}" # YOUR CODE HERE
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    response = requests.get(base_url, params=params) # YOUR CODE HERE
    
    # Convert the API response to JSON format
    name_address = response.json() # YOUR CODE HERE
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# cabo san lucas - nearest hotel: Comfort Rooms
# tiksi - nearest hotel: Арктика
# hawaiian paradise park - nearest hotel: No hotel found
# antonio enes - nearest hotel: Hotel Quirimbas
# port-aux-francais - nearest hotel: Keravel
# palikir - national government center - nearest hotel: No hotel found
# akureyri - nearest hotel: Hótel Norðurland
# lompoc - nearest hotel: Red Roof Inn Lompoc
# igarka - nearest hotel: Заполярье
# maridi - nearest hotel: No hotel found
# punta arenas - nearest hotel: Hotel Lacolet
# ribas do rio pardo - nearest hotel: Hotel São Francisco
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# port mathurin - nearest hotel: Escale Vacances
# ghadamis - nearest hotel: فندق عين الفارس
# la foa - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# singkil - nearest hotel: No hotel found
# constantia - nearest hotel: Hotel Chérica
# udachny - nearest hotel: Вилюй
# aasiaat - nearest hotel: SØMA
# ribeira grande - nearest hotel: No hotel found
# shar - nearest hotel: Бейсенов
# touros - nearest hotel: Pousada Atlântico
# hadibu - nearest hotel: No hotel found
# dudinka - nearest hotel: Виктория
# utrik - nearest hotel: No hotel found
# canutama - nearest hotel: No hotel found
# edinburgh of the seven seas - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: No hotel found
# severo-yeniseyskiy - nearest hotel: Актолик
# goba - nearest hotel: ጎባ ዋቤ ሸበሌ ሆቴል
# polyarnyy - nearest hotel: No hotel found
# lospalos - nearest hotel: Hotel Roberto Carlos
# susuman - nearest hotel: No hotel found
# albany - nearest hotel: No hotel found
# panama city beach - nearest hotel: Shores of Panama
# nova sintra - nearest hotel: Residência Ka Dencho
# tartouss - nearest hotel: فندق انترادوس
# nuuk - nearest hotel: Nordbo
# jamestown - nearest hotel: DoubleTree Jamestown
# thompson - nearest hotel: Thompson Inn
# isafjordur - nearest hotel: Hótel Horn
# aykhal - nearest hotel: No hotel found
# portage la prairie - nearest hotel: Microtel Inn and Suites by Wyndham Portage La Prairie
# polyany - nearest hotel: No hotel found
# baiyin - nearest hotel: 红鹭宾馆
# metlili chaamba - nearest hotel: No hotel found
# kodiak - nearest hotel: No hotel found
# happy valley-goose bay - nearest hotel: Hotel North Two
# veinticinco de mayo - nearest hotel: Jorly
# ismailia - nearest hotel: Mercure
# santa ana hueytlalpan - nearest hotel: Dilivher
# bredasdorp - nearest hotel: Victoria Hotel
# uturoa - nearest hotel: Hawaiki Nui hotel
# port alfred - nearest hotel: No hotel found
# yellowknife - nearest hotel: No hotel found
# beauvais - nearest hotel: No hotel found
# lerwick - nearest hotel: Grand Hotel
# grytviken - nearest hotel: No hotel found
# kidatu - nearest hotel: No hotel found
# mariental - nearest hotel: Mariental Hotel
# antsiranana - nearest hotel: Central
# prince rupert - nearest hotel: Crest Hotel
# klyuchi - nearest hotel: No hotel found
# claveria - nearest hotel: Lakay-Lakay Beach Resort
# blackmans bay - nearest hotel: Villa Howden
# margaret river - nearest hotel: Margaret River Hotel
# papatowai - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# talnakh - nearest hotel: Талнах
# iqaluit - nearest hotel: Frobisher Inn
# alofi - nearest hotel: No hotel found
# kathu - nearest hotel: B&B NAMO PHUKET
# olonkinbyen - nearest hotel: No hotel found
# waitangi - nearest hotel: Hotel Chathams
# tuy hoa - nearest hotel: Nhu Y Hotel
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# hithadhoo - nearest hotel: Pebbles Inn
# ola - nearest hotel: No hotel found
# parang - nearest hotel: No hotel found
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# uliastay - nearest hotel: Болоржин зочид буудал
# tokar - nearest hotel: No hotel found
# atafu village - nearest hotel: No hotel found
# corbelia - nearest hotel: Peroza Restaurante Hotel
# kiunga - nearest hotel: No hotel found
# stanley - nearest hotel: Hotel 52
# colares - nearest hotel: Hotel Arribas
# grand gaube - nearest hotel: Hotel Lux- Grand Gaube
# yaren - nearest hotel: Aiwo Hotel
# afaahiti - nearest hotel: Omati Lodge
# rundu - nearest hotel: Kavango River Lodge
# banda aceh - nearest hotel: Hotel 61
# cunit - nearest hotel: Lleida
# kargasok - nearest hotel: Титан
# krasnaya gorbatka - nearest hotel: Елизаветинский
# kohat - nearest hotel: No hotel found
# justo daract - nearest hotel: No hotel found
# al kharijah - nearest hotel: Kharga Hotel
# georgetown - nearest hotel: Page 63 hostel
# dodoma - nearest hotel: Hilton Lodge 2
# whitehorse - nearest hotel: Town & Mountain Hotel
# pamandzi - nearest hotel: Gite Le Madina
# toliara - nearest hotel: Ambary
# hermanus - nearest hotel: Aloe guest house
# port elizabeth - nearest hotel: Waterford Hotel
# n'dalatando - nearest hotel: Hotel Terminus
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# zhanaozen - nearest hotel: No hotel found
# new norfolk - nearest hotel: Woodbridge on the Derwent
# knyaze-volkonskoye - nearest hotel: No hotel found
# mramani - nearest hotel: No hotel found
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# al ghayzah - nearest hotel: فندق تاج العرب
# kamaishi - nearest hotel: 釜石ベイシティホテル
# usogorsk - nearest hotel: Единственная
# petauke - nearest hotel: No hotel found
# undurkhaan - nearest hotel: Khanburged Hotel
# muar - nearest hotel: Hotel Leewa
# chiang kham - nearest hotel: ChiangKham Hotel
# west island - nearest hotel: Cocos Village Bungalows
# lodeynoye pole - nearest hotel: Лодейка
# albertina - nearest hotel: No hotel found
# luis correia - nearest hotel: Hotel Amaro
# san luis de la loma - nearest hotel: No hotel found
# trinidad - nearest hotel: Hotel Palace
# kalmunai - nearest hotel: Saji new food
# invercargill - nearest hotel: The Grand
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# nizhnyaya salda - nearest hotel: No hotel found
# anadyr - nearest hotel: Гостевой дом
# the bottom - nearest hotel: Queen's Garden Resort
# kuqa - nearest hotel: Kuqa Hotel - foreigners accepted
# chazuta - nearest hotel: No hotel found
# lihue - nearest hotel: Kauai Palms
# khoyniki - nearest hotel: Журавінка
# semporna - nearest hotel: Sipadan Inn II
# crane - nearest hotel: No hotel found
# holualoa - nearest hotel: Kona Hotel
# arkhangel'sk - nearest hotel: Серафима
# pacocha - nearest hotel: Gran Hotel Ilo
# ghat - nearest hotel: فندق تاسيلي
# keflavik - nearest hotel: Núpan Deluxe
# illizi - nearest hotel: بوناقة
# ulladulla - nearest hotel: Hotel Marlin
# manaure - nearest hotel: hotel palaima
# barra de santo antonio - nearest hotel: No hotel found
# nizhnesortymskiy - nearest hotel: Нижнесортымский
# howrah - nearest hotel: Sun India Guest House
# ocean shores - nearest hotel: Collins Inn & Seaside Cottages
# khandyga - nearest hotel: Апельсин
# nasiriyah - nearest hotel: فندق حمورابي
# karratha - nearest hotel: Karratha International Hotel
# cannonvale - nearest hotel: Whitsundays Rainforest Retreat
# nerchinsk - nearest hotel: No hotel found
# tura - nearest hotel: Hotel Polo Orchid
# grand falls-windsor - nearest hotel: Hotel Robin Hood
# gisborne - nearest hotel: Portside Hotel
# wewak - nearest hotel: Boutique Hotel 2
# kampene - nearest hotel: No hotel found
# khovd - nearest hotel: Khovd hotel
# burang - nearest hotel: No hotel found
# dzhambeyty - nearest hotel: Алаш
# maiurno - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# bolanikhodan - nearest hotel: No hotel found
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# birobidzhan - nearest hotel: Мини-гостиница
# brookings - nearest hotel: Quality Inn
# ar raqqah - nearest hotel: Al Sari
# grand island - nearest hotel: Grand Island Travelodge
# crossville - nearest hotel: TownePlace Suites
# copiapo - nearest hotel: Hotel Diego de Almeida
# lockwood - nearest hotel: Holiday Inn Express
# san jose de jachal - nearest hotel: San Martin
# minas de marcona - nearest hotel: No hotel found
# gagliano del capo - nearest hotel: Masseria Palane
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# puerto aysen - nearest hotel: Hostal Dendal
# saint-philippe - nearest hotel: Le Baril
# taybad - nearest hotel: No hotel found
# buka - nearest hotel: No hotel found
# panna - nearest hotel: No hotel found
# twon-brass - nearest hotel: KC Hotel
# yangchun - nearest hotel: No hotel found
# saudarkrokur - nearest hotel: Mikligarður
# albufeira - nearest hotel: Hotel Baltum
# ferkessedougou - nearest hotel: Ferké Hôtel Iroko
# paracuru - nearest hotel: Vento Brasil
# vorkuta - nearest hotel: "Мегаполис"
# port shepstone - nearest hotel: The Spot Backpackers'
# huarmey - nearest hotel: Hostal Santa Rosa
# kapa'a - nearest hotel: Pono Kai Resort
# chilapa de alvarez - nearest hotel: No hotel found
# kutulik - nearest hotel: Гостиница
# sungai penuh - nearest hotel: Hotel Matahari
# barcelos - nearest hotel: Hotel Dom Nuno
# harper - nearest hotel: No hotel found
# port saint john's - nearest hotel: Outback Inn
# maceio - nearest hotel: Maceió Hostel e Pousada
# howard springs - nearest hotel: No hotel found
# pont rouge - nearest hotel: No hotel found
# balikpapan - nearest hotel: Hotel Grand Senyiur
# tupiza - nearest hotel: Aramayo Hostal
# palma di montechiaro - nearest hotel: No hotel found
# sandnessjoen - nearest hotel: Scandic Syv Søstre
# ikalamavony - nearest hotel: No hotel found
# yenangyaung - nearest hotel: No hotel found
# lagoa - nearest hotel: Casa da Madrinha
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# kovrov - nearest hotel: Визит
# bahir dar - nearest hotel: ናኪ ሆቴል
# newman - nearest hotel: No hotel found
# berezovo - nearest hotel: Град Березов
# khorixas - nearest hotel: iGowati Country Hotel and Lodge
# morondava - nearest hotel: Hotel Sharon Menabe
# yugorsk - nearest hotel: Студенческая
# 'alaqahdari dishu - nearest hotel: No hotel found
# juneau - nearest hotel: Ramada by Wyndham Juneau
# ad dabbah - nearest hotel: No hotel found
# pizarro - nearest hotel: No hotel found
# vegreville - nearest hotel: Vegreville Suites
# portland - nearest hotel: the Hoxton
# nago - nearest hotel: グリーンリッチホテル
# argenton-sur-creuse - nearest hotel: Hapimag
# sao vicente - nearest hotel: Pousada Vitória
# calingasta - nearest hotel: Nora Hôtel
# nemuro - nearest hotel: お宿エクハシ
# argo - nearest hotel: Apollon Hotel
# kone - nearest hotel: Pacifik Appartels
# praia da vitoria - nearest hotel: Salles
# vilyuysk - nearest hotel: Мария
# xucheng - nearest hotel: No hotel found
# alesund - nearest hotel: Brosundet
# sinop - nearest hotel: No hotel found
# gembu - nearest hotel: No hotel found
# jaisalmer - nearest hotel: Jeet Mahal
# laguna - nearest hotel: Holiday Inn Express & Suites
# saint-louis - nearest hotel: No hotel found
# kralendijk - nearest hotel: Hotel Bonaire Inn
# road town - nearest hotel: No hotel found
# salinas - nearest hotel: The Traveler's Hotel
# lourical - nearest hotel: No hotel found
# uddevalla - nearest hotel: Carlia
# lisse - nearest hotel: Hotel De Duif
# beytussebap - nearest hotel: No hotel found
# dryden - nearest hotel: Holiday Inn Express
# san antonio de pale - nearest hotel: No hotel found
# karaton - nearest hotel: Orange Syariah
# livermore - nearest hotel: Del Valle Lodge
# ingeniero guillermo n. juarez - nearest hotel: Hotel El Indiano
# yeniseysk - nearest hotel: Отель Енисейский
# geraldton - nearest hotel: Ocean Centre Hotel
# itigi - nearest hotel: Puma guesthouse
# okahandja - nearest hotel: Okahandja Country Hotel
# sokur - nearest hotel: No hotel found
# smithers - nearest hotel: Sunshine Inn Hotel
# gordonvale - nearest hotel: No hotel found
# valdovino - nearest hotel: Camino Surfcamp Galicia
# katsuren-haebaru - nearest hotel: No hotel found
# arnstadt - nearest hotel: Thüringer Kloßhotel "Goldene Henne"
# black point - nearest hotel: No hotel found
# saint-joseph - nearest hotel: No hotel found
# chita - nearest hotel: No hotel found
# tarakan - nearest hotel: Hotel Dynasty
# borogontsy - nearest hotel: No hotel found
# tabuk - nearest hotel: Davidson Hotel
# omutinskiy - nearest hotel: No hotel found
# quepos - nearest hotel: Casa Feliz
# rabo de peixe - nearest hotel: Pico do Refugio
# ntoum - nearest hotel: Santa Barbara
# mahina - nearest hotel: Motu Martin
# gaalkacyo - nearest hotel: Citycenter وسط المدينة
# mirny - nearest hotel: Зарница
# bereznik - nearest hotel: Отель Прибрежный
# kailua-kona - nearest hotel: Kona Seaside Hotel
# kotlas - nearest hotel: Советская
# melekeok village - nearest hotel: No hotel found
# yanam - nearest hotel: Hôtel Sarvainn
# isetskoye - nearest hotel: Стриж
# awjilah - nearest hotel: No hotel found
# loango - nearest hotel: Hotel des Aigles
# sinan - nearest hotel: No hotel found
# niquelandia - nearest hotel: Serrano Hotel
# puro - nearest hotel: No hotel found
# bubaque - nearest hotel: Chez Julio
# nantucket - nearest hotel: No hotel found
# guarda - nearest hotel: Hotel Vanguarda
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# zouerate - nearest hotel: فندق تيرس زمور
# yung shue wan - nearest hotel: 浪濤軒酒店 Concerto Inn
# oranjemund - nearest hotel: No hotel found
# rongelap - nearest hotel: No hotel found
# papao - nearest hotel: Hiti Moana Villa Lodge
# narathiwat - nearest hotel: No hotel found
# shagonar - nearest hotel: No hotel found
# olinda - nearest hotel: Fidji Motel
# kurchatov - nearest hotel: Россия
# preobrazheniye - nearest hotel: No hotel found
# hami - nearest hotel: No hotel found
# qa'en - nearest hotel: No hotel found
# baiao - nearest hotel: No hotel found
# antu - nearest hotel: No hotel found
# zaozersk - nearest hotel: Северное сияние
# koungou - nearest hotel: Hôtel Trévani
# azemmour - nearest hotel: No hotel found
# tadine - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
# erdenet - nearest hotel: No hotel found
# bathsheba - nearest hotel: Atlantis Hotel
# sao felix do xingu - nearest hotel: Hotel Terraço
# callao - nearest hotel: Casa Ronald
# luganville - nearest hotel: Beachfront Resort
# taroa - nearest hotel: No hotel found
# thinadhoo - nearest hotel: No hotel found
# mogocha - nearest hotel: 7Ka
# hengchun - nearest hotel: 海的顏色精品旅館
# malango - nearest hotel: Madarana
# gobabis - nearest hotel: Kalahari Convention Centre Hotel
# conception bay south - nearest hotel: No hotel found
# iyidere - nearest hotel: Babillon Hotel
# pandan - nearest hotel: No hotel found
# barra dos coqueiros - nearest hotel: Grande Hotel
# mejit - nearest hotel: No hotel found
# bandar lampung - nearest hotel: Grand Anugerah
# i-n-salah - nearest hotel: باجودة
# baharly - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: Complexe Belova
# wenchang - nearest hotel: No hotel found
# sigaboy - nearest hotel: No hotel found
# dampit - nearest hotel: No hotel found
# whakatane - nearest hotel: Whakatane Hotel
# cumaral - nearest hotel: Hotel San Francisco
# okha - nearest hotel: Сфера
# trinity beach - nearest hotel: Blue Lagoon Resort
# chios - nearest hotel: Aegean Sea
# kulhudhuffushi - nearest hotel: No hotel found
# yokadouma - nearest hotel: Hôtel Grand Moulin
# chibougamau - nearest hotel: No hotel found
# kununurra - nearest hotel: No hotel found
# panzos - nearest hotel: No hotel found
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# san pablo villa de mitla - nearest hotel: Don Aji
# roorkee - nearest hotel: No hotel found
# ust-nera - nearest hotel: гостиница "Солнечная"
# tobol'sk - nearest hotel: Ямская
# barmer - nearest hotel: Janta Cafe & Restaurant
# kismayo - nearest hotel: Kismayo Hotel
# vuktyl - nearest hotel: Вуктыл
# bogande - nearest hotel: No hotel found
# tarawa - nearest hotel: No hotel found
# aoulef - nearest hotel: دار الضياف
# merizo village - nearest hotel: No hotel found
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# la cruz - nearest hotel: Hotel Las Palmas
# parras de la fuente - nearest hotel: Posada Santa isabel
# bulawayo - nearest hotel: Selboune Hotel
# kitui - nearest hotel: Parkside Hotel
# white city - nearest hotel: Brookside
# nadi - nearest hotel: President Hotel
# santa ines - nearest hotel: Hotel Carajás
# banjar - nearest hotel: Villa Banjar Beach
# cape coast - nearest hotel: Mighty Victory Hotel
# pisco - nearest hotel: La Portada
# an nuhud - nearest hotel: No hotel found
# china - nearest hotel: No hotel found
# asha - nearest hotel: Аша
# price - nearest hotel: Quality Inn Price Gateway To Moab National Parks
# kiruna - nearest hotel: The Bishops Inn
# palmeira - nearest hotel: Hotel Vereda
# arauco - nearest hotel: No hotel found
# nadym - nearest hotel: Янтарная
# kolokani - nearest hotel: Hôtel kolokani
# guajara mirim - nearest hotel: Novo Hotel Campos
# bikenibeu village - nearest hotel: Otintaai Hotel
# tromso - nearest hotel: Clarion Collection Hotel Aurora
# candido mendes - nearest hotel: No hotel found
#                        City Country      Lat       Lng  Humidity  \
# 0            cabo san lucas      MX  22.8909 -109.9124        70
# 1                     tiksi      RU  71.6872  128.8694        83
# 2    hawaiian paradise park      US  19.5933 -154.9731        98
# 3              antonio enes      MZ -16.2325   39.9086        68
# 4         port-aux-francais      TF -49.3500   70.2167        78
# ..                      ...     ...      ...       ...       ...
# 587                kolokani      ML  13.5728   -8.0339        13
# 588           guajara mirim      BR -10.7828  -65.3394        74
# 589       bikenibeu village      KI   1.3673  173.1241        84
# 590                  tromso      NO  69.6496   18.9570        55
# 591          candido mendes      BR  -1.4467  -45.7167        61
#
#                           Hotel Name
# 0                      Comfort Rooms
# 1                            Арктика
# 2                     No hotel found
# 3                    Hotel Quirimbas
# 4                            Keravel
# ..                               ...
# 587                   Hôtel kolokani
# 588                Novo Hotel Campos
# 589                   Otintaai Hotel
# 590  Clarion Collection Hotel Aurora
# 591                   No hotel found
#
# [592 rows x 6 columns]

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
city_map_with_hotels = hotel_df.hvplot.points(
    x='Lng',
    y='Lat',
    c='Humidity',
    colormap='viridis',  # You can choose a different colormap if desired
    size='Humidity',     # Set the size of points based on humidity
    title='City Humidity',
    xlabel='Longitude',
    ylabel='Latitude',
    hover_cols=['City', 'Country', 'Hotel Name', 'Humidity'],
    colorbar=True,
    grid=True,
    coastline=True,
    tiles = True,
    frame_width = 700,
    frame_height = 500,
)


# Display the map
# YOUR CODE HERE
# Display the map with hotels and additional hover information
city_map_with_hotels
# Out:
# :Overlay
#    .WMTS.I      :WMTS   [Longitude,Latitude]
#    .Points.I    :Points   [Lng,Lat]   (Humidity,City,Country,Hotel Name)
#    .Coastline.I :Feature   [Longitude,Latitude]
